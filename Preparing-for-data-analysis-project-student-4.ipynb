# %% [markdown]
# # Course 2 Project: ML Pipeline for Feature Engineering

# %% [markdown]
# ## Instructions
#
# In this project, you'll use data related to microeconomic indicators and historical stock prices to explore the data engineering pipline. You'll get to practice:
#
# * Data ingestion
# * Data cleaning
# * Data imputation
# * Exploratory data analysis (EDA) through charts and graphs

# %% [markdown]
# ## Packages
#
# You'll use `pandas` and `matplotlib`, which were covered in the course material, to import, clean, and plot data. They have been installed in this workspace for you. If you're working locally and you installed Jupyter using Anaconda, these packages will already be installed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load data
#
# The first step in a data engineering pipeline for machine learning is to ingest the data that will be used. For this project, data is hosted on a public GitHub repo.
#
# ### Your tasks
# * Import data from the provided [GitHub repo](https://github.com/udacity/CD13649-Project/tree/main/Project) using `pandas`. For your convenience, the data files (CSVs) are also present in the current workspace at the path **CD13649-Project/Project/**. Here are the data files to import:
#   1. GDP (**GDP.csv**)
#   2. Inflation (**inflation_monthly.csv**)
#   3. Apple stock prices (**apple_historical_data.csv**)
#   4. Microsoft stock prices (**microsoft_historical_data.csv**)
#   5. Consumer price index (**consumer_price_index.csv**)
#
#
#
# * Verify that the data has been imported correctly into `pandas` dataframes. Use methods like `head()` and `info()`
#
#
# * You may need to change column names to make them easier to work with
#
#
# * You may need to cast datetime data to the `datetime` format using `pandas` `to_datetime()` method

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load historical GDP data
Data = pd.read_csv('GDP.csv')   ###https://www.geeksforgeeks.org/reading-csv-files-in-python/

# %%
# Check the first few rows of data
Data.head()
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742

# %%
# Load the historical stock price data for Apple and Microsoft  
Data2= pd.read_csv('microsoft_historical_data.csv')   #https://www.geeksforgeeks.org/reading-csv-files-in-python/
Data3= pd.read_csv('apple_historical_data.csv')       #https://www.geeksforgeeks.org/reading-csv-files-in-python/

# %%
# Check the first few rows of data
Data2.head()
Data3.head()

Combined_data = pd.concat([Data2, Data3])
Combined_data.head()
display(Combined_data)
# Out:
#             Date Close/Last     Volume     Open       High        Low
# 0     05/03/2024    $406.66   17446720  $402.28    $407.15    $401.86
# 1     05/02/2024    $397.84   17709360  $397.66    $399.93  $394.6515
# 2     05/01/2024    $394.94   23562480  $392.61  $401.7199    $390.31
# 3     04/30/2024    $389.33   28781370  $401.49    $402.16    $389.17
# 4     04/29/2024    $402.25   19582090  $405.25    $406.32    $399.19
# ...          ...        ...        ...      ...        ...        ...
# 2512   5/12/2014    $21.17   212736019  $20.98     $21.20     $20.98
# 2513    5/9/2014    $20.91   291068564  $20.88     $20.94     $20.73
# 2514    5/8/2014    $21.00   228973884  $21.01     $21.23     $20.94
# 2515    5/7/2014    $21.15   282128727  $21.26     $21.33     $20.99
# 2516    5/6/2014    $21.23   373872650  $21.49     $21.59     $21.23
#
# [5034 rows x 6 columns]

# %%
# Use methods like .info() and .describe() to explore the data
Data2.info()
Data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2517 non-null   object
#  1   Close/Last  2517 non-null   object
#  2   Volume      2517 non-null   int64
#  3   Open        2517 non-null   object
#  4   High        2517 non-null   object
#  5   Low         2517 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 118.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2517 non-null   object
#  1   Close/Last  2514 non-null   object
#  2   Volume      2517 non-null   int64
#  3   Open        2517 non-null   object
#  4   High        2517 non-null   object
#  5   Low         2517 non-null   object
# dtypes: int64(1), object(5)
# ...

# %% [markdown]
# ## Data preprocessing: Check for missing data and forward fill
#
# Check the Apple historical prices for missing data. Check for missing data in all columns. If there's data missing, use a forward fill to fill in those missing prices.

# %%
# Check for nulls 
Data3.isnull()      #https://www.w3schools.com/python/pandas/ref_df_isnull.asp
# Out:
#        Date  Close/Last  Volume   Open   High    Low
# 0     False       False   False  False  False  False
# 1     False       False   False  False  False  False
# 2     False       False   False  False  False  False
# 3     False       False   False  False  False  False
# 4     False       False   False  False  False  False
# ...     ...         ...     ...    ...    ...    ...
# 2512  False       False   False  False  False  False
# 2513  False       False   False  False  False  False
# 2514  False       False   False  False  False  False
# 2515  False       False   False  False  False  False
# 2516  False       False   False  False  False  False
#
# [2517 rows x 6 columns]

# %%
# Forward fill any missing data
#No null values found in Apple historical data

# %%
# Check again for nulls after using forward fill
Data3.isnull()   #https://www.w3schools.com/python/pandas/ref_df_isnull.asp
# Out:
#        Date  Close/Last  Volume   Open   High    Low
# 0     False       False   False  False  False  False
# 1     False       False   False  False  False  False
# 2     False       False   False  False  False  False
# 3     False       False   False  False  False  False
# 4     False       False   False  False  False  False
# ...     ...         ...     ...    ...    ...    ...
# 2512  False       False   False  False  False  False
# 2513  False       False   False  False  False  False
# 2514  False       False   False  False  False  False
# 2515  False       False   False  False  False  False
# 2516  False       False   False  False  False  False
#
# [2517 rows x 6 columns]

# %% [markdown]
# ## Data preprocessing: Remove special characters and convert to numeric/datetime
#
# The next step in the data engineering process is to standardize and clean up data. In this step, you'll check for odd formatting and special characters that will make it difficult to work with data as numeric or datetime.
#
# In this step:
# * Create a function that takes in a dataframe and a list of columns and removes dollar signs ('$') from those columns
# * Convert any columns with date/time data into a `pandas` `datetime` format

# %%
def convert_dollar_columns_to_numeric(x):
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return (x)
    
#https://pbpython.com/currency-cleanup.html

# %%
# Use convert_dollar_columns_to_numeric() to remove the dollar sign from the Apple and Microsoft datasets

Data2['Close/Last'] = Data2['Close/Last'].apply(convert_dollar_columns_to_numeric).astype('float')
Data2['Open'] = Data2['Open'].apply(convert_dollar_columns_to_numeric).astype('float')
Data2['High'] = Data2['High'].apply(convert_dollar_columns_to_numeric).astype('float')
Data2['Low'] = Data2['Low'].apply(convert_dollar_columns_to_numeric).astype('float')

Data2.head()
Data3['Close/Last'] = Data3['Close/Last'].apply(convert_dollar_columns_to_numeric).astype('float')
Data3['Open'] = Data3['Open'].apply(convert_dollar_columns_to_numeric).astype('float')
Data3['High'] = Data3['High'].apply(convert_dollar_columns_to_numeric).astype('float')
Data3['Low'] = Data3['Low'].apply(convert_dollar_columns_to_numeric).astype('float')

Data2.head()
Data3.head()
# Out:
#         Date  Close/Last     Volume    Open    High     Low
# 0   5/3/2024      183.38  163224100  186.65  187.00  182.66
# 1   5/2/2024      173.03   94214920  172.51  173.42  170.89
# 2   5/1/2024      169.30   50383150  169.58  172.71  169.11
# 3  4/30/2024      170.33   65934780  173.33  174.99  170.00
# 4  4/29/2024      173.50   68169420  173.37  176.03  173.10

# %%
# Use pandas's to_datetime() to convert any columns that are in a datetime format
Data2['Date'] = pd.to_datetime(Data2['Date'])
Data2.head()

Data3['Date'] = pd.to_datetime(Data3['Date'])
Data3.head()

##https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
# Out:
#         Date  Close/Last     Volume    Open    High     Low
# 0 2024-05-03      183.38  163224100  186.65  187.00  182.66
# 1 2024-05-02      173.03   94214920  172.51  173.42  170.89
# 2 2024-05-01      169.30   50383150  169.58  172.71  169.11
# 3 2024-04-30      170.33   65934780  173.33  174.99  170.00
# 4 2024-04-29      173.50   68169420  173.37  176.03  173.10

# %%
# Use .info() and check the type of each column to ensure that the above steps worked

Data2.info()
Data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2517 non-null   datetime64[ns]
#  1   Close/Last  2517 non-null   float64
#  2   Volume      2517 non-null   int64
#  3   Open        2517 non-null   float64
#  4   High        2517 non-null   float64
#  5   Low         2517 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 118.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2517 non-null   datetime64[ns]
#  1   Close/Last  2514 non-null   float64
#  2   Volume      2517 non-null   int64
#  3   Open        2517 non-null   float64
#  4   High        2517 non-null   float64
#  5   Low         2517 non-null   float64
# ...

# %% [markdown]
# ## Data preprocessing: Align datetime data
#
# Data engineering includes changing data with a datetime component if needed so that different time series can be more easily compared or plotted against each other.
#
# In this step:
#
# * Align the inflation date so that it falls on the last day of the month instead of the first
#
# Helpful hints:
# * Use the `pandas` `offsets` method using `MonthEnd(0)` to set the 'Date' column to month-end

# %%
# Align inflation data so that the date is the month end (e.g. Jan 31, Feb 28/28)
Inflation_data = pd.read_csv('inflation_monthly.csv')
Inflation_data['DATE'] = pd.to_datetime(Inflation_data['DATE'])
Inflation_data['DATE'] = Inflation_data['DATE'] + pd.offsets.MonthEnd(0)

Inflation_data.head()

##https://www.geeksforgeeks.org/python-pandas-tseries-offsets-dateoffset/
# Out:
#         DATE  CORESTICKM159SFRBATL
# 0 1968-01-31              3.651861
# 1 1968-02-29              3.673819
# 2 1968-03-31              4.142164
# 3 1968-04-30              4.155828
# 4 1968-05-31              4.088245

# %% [markdown]
# ## Data preprocessing: Upsample, downsample and interpolate data
#
# Inflation data is presented monthly in this dataset. However, for some models, you may need it at a quarterly frequency, and for some models you may need it at a quarterly frequency.
#
# In this step:
# * Create a new quarterly inflation dataframe by downsampling the monthly inflation data to quarterly using the mean (e.g. for quarter 1 in a given year, use the average values from January, February, and March)
# * Create a new weekly inflation dataframe by upsampling the monthly inflation data. For this, you'll need to use `resample` and then you'll need to `interpolate` to fill in the missing data at the weekly frequency
#
# Note that you may need to change the index for some of these operations!

# %%
# Upsample and interpolate from monthly to weekly 
Inflation_data.set_index('DATE', inplace=True)
Inflation_data_weekly = Inflation_data.resample('W').ffill()    #https://stackoverflow.com/questions/66874373/pandas-resample-monthly-data-to-weekly-within-groups-and-split-values 
Inflation_data_weekly.head()
# Out:
#             CORESTICKM159SFRBATL
# DATE
# 1968-02-04              3.651861
# 1968-02-11              3.651861
# 1968-02-18              3.651861
# 1968-02-25              3.651861
# 1968-03-03              3.673819

# %%
# Downsample from monthly to quarterly 
Inflation_data = pd.read_csv('inflation_monthly.csv')
Inflation_data['DATE'] = pd.to_datetime(Inflation_data['DATE'])
Inflation_data.set_index('DATE').resample('QE').agg(lambda x: x.iloc[:3].mean())
# Out:
#             CORESTICKM159SFRBATL
# DATE
# 1968-03-31              3.822615
# 1968-06-30              4.263214
# 1968-09-30              4.882643
# 1968-12-31              5.429443
# 1969-03-31              5.873770
# ...                          ...
# 2023-03-31              6.467833
# 2023-06-30              5.942054
# 2023-09-30              5.179249
# 2023-12-31              4.708539
# 2024-03-31              4.505412
#
# [225 rows x 1 columns]

# %% [markdown]
# ## Data preprocessing: Normalize/standardize a feature
#
# Economic time series data often involve variables measured on different scales (e.g., GDP in trillions of dollars, inflation in percentage points). Standardizing these variables (typically by subtracting the mean and dividing by the standard deviation) puts them on a common scale, allowing for meaningful comparisons and analyses.
#
# Your task:
# * Standardize the GDP data. You may do this manually by subtracting the mean and dividing by the standard deviation, or you may use a built-in method from a library like `sklearn`'s `StandardScaler`

# %%
# Standardize the GDP measure
from sklearn.preprocessing import StandardScaler
Data.info()
Data.head()
Data.dropna(inplace=True)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(Data[['GDP']])
Data['GDP_standardized']= X_scaled
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    309 non-null    object
#  1   GDP     309 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.0+ KB

# %%
# Check the dataframe to make sure the calculation worked as expected 
Data.head()
# Out:
#          DATE      GDP  GDP_standardized
# 0  1947-01-01  243.164         -0.935496
# 1  1947-04-01  245.968         -0.935121
# 2  1947-07-01  249.585         -0.934636
# 3  1947-10-01  259.745         -0.933276
# 4  1948-01-01  265.742         -0.932472

# %% [markdown]
# ## EDA: Plotting a time series of adjusted open vs close price
#
# As part of your EDA, you'll frequently want to plot two time series on the same graph and using the same axis to compare their movements.
#
# Your task:
# * Plot the Apple open and close price time series on the same chart **for the last three months only**. Be sure to use a legend to label each line
#
# **NOTE**: This is a large dataset. If you try to plot the entire series, your graph will be hard to interpret and may take a long time to plot. Be sure to use only the most recent three months of data.

# %%
# Get max date in timeseries
Data3['Date'] = pd.to_datetime(Data3['Date'])

Data3.set_index('Date', inplace=True)

# %%
# Use the max date calculated above to get the last three months of data in the dataset 

latest_date = Data3.index.max()
three_months = latest_date - pd.DateOffset(months=3)
last_three_months = Data3[Data3.index >= three_months]
display(last_three_months)
# Out:
#             Close/Last     Volume    Open    High     Low
# Date
# 2024-05-03      183.38  163224100  186.65  187.00  182.66
# 2024-05-02      173.03   94214920  172.51  173.42  170.89
# 2024-05-01      169.30   50383150  169.58  172.71  169.11
# 2024-04-30      170.33   65934780  173.33  174.99  170.00
# 2024-04-29      173.50   68169420  173.37  176.03  173.10
# ...                ...        ...     ...     ...     ...
# 2024-02-09      188.85   45155220  188.65  189.99  188.00
# 2024-02-08      188.32   40962050  189.39  189.54  187.35
# 2024-02-07      189.41   53438960  190.64  191.05  188.61
# 2024-02-06      189.30   43490760  186.86  189.31  186.77
# 2024-02-05      187.68   69668820  188.15  189.25  185.84
#
# [63 rows x 5 columns]

# %%
# Plot time series of open v. close stock price for Apple using the last 3 months of data
#Visualize the closing price 
plt.figure(figsize=(12,6))
plt.plot(last_three_months['Close/Last'], label='Close')
plt.plot(last_three_months['Open'], label= 'Open')
plt.title(f" Closing and opening Price time series")
plt.xlabel("Date")
plt.ylabel("Close price (USD)")
plt.legend()
plt.show()

# %% [markdown]
# ## EDA: Plotting a histogram of a stock's closing price in the last three months
#
# One way to see how much a stock's price generally moves is to plot the frequency of closing prices over a set time period.
#
# Your task:
# * Use the **last three months** of Apple stock data and plot a histogram of closing price

# %%
# Plot the histogram of Apple's closing price over the last 3 months 
number_of_bins = int(np.log2(len(last_three_months))) + 1   ###sturges rule 

sns.histplot(last_three_months['Close/Last'], bins = number_of_bins, kde= True, color='lightblue', edgecolor='white')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Customized Histogram with closing prices for AAPL')
plt.show()

# %% [markdown]
# ## Calculating correlation between a stock price and a macroeconomic variable
#
# Inflation affects the purchasing power of money and can influence corporate profits, interest rates, and consumer behavior. By analyzing the correlation between stock prices and inflation, one can gauge how inflationary trends impact stock market performance. For instance, high inflation might erode profit margins and reduce stock prices, while moderate inflation might indicate a growing economy, benefiting stocks.
#
# Your task:
# * Plot a heatmap that shows the correlation between Microsoft and Apple returns and inflation
#
# This will require several steps:
# 1. Calculate the returns for Apple and Microsoft and the change in monthly inflation (use the `pct_change` method for each)
# 2. Interpolate the daily stock returns data to monthly so it can be compared to the monthly inflation data
# 3. Merge the stock returns (Apple and Microsoft) and inflation data series into a single dataframe
# 4. Calculate the correlation matrix between the Apple returns, Microsoft returns, and inflation change
# 5. Plot the correlation matrix as a heatmap

# %% [markdown]
# ### 1. Calculate returns for Microsoft / Apple and the monthly change in inflation

# %%
# Calculate daily returns for Apple and Microsoft and the percent change in inflation from month to month
Data_two= pd.read_csv('microsoft_historical_data.csv') 
Data_two['Close/Last'] = Data_two['Close/Last'].apply(convert_dollar_columns_to_numeric).astype('float')
Data_two.head()
Data_M = Data_two[['Date','Close/Last']]
Data_M.head()
def computing_returns(Data_M, list_of_momentums):
    list_of_momentums = [1]
    for i in list_of_momentums:
        Data_M_numeric = Data_M.select_dtypes(include=['float64', 'int64'])
        feature = Data_M_numeric.pct_change(i)
        name = str(i) + "_d_returns"
        feature = feature.copy()
        feature.rename(columns = {0: name}, inplace = True)
        total_returns = feature
        total_returns.dropna(axis=0, how='any', inplace=True)

    return total_returns
total_returns = computing_returns(Data_M, list_of_momentums=1)
total_returns['Date'] = Data_M['Date'].iloc[1:].values

#Apple stock data
Data_three= pd.read_csv('apple_historical_data.csv') 
Data_three['Close/Last'] = Data_three['Close/Last'].apply(convert_dollar_columns_to_numeric).astype('float')
Data_A = Data_three[['Date','Close/Last']]

def computing_returns(Data_A, list_of_momentums):
    list_of_momentums = [1]
    for i in list_of_momentums:
        Data_A_numeric = Data_A.select_dtypes(include=['float64', 'int64'])
        feature_a = Data_A_numeric.pct_change(i)
        name = str(i) + "_d_returns"
        feature_a = feature_a.copy()
        feature_a.rename(columns = {0: name}, inplace = True)
        total_returns_a = feature_a
        total_returns_a.dropna(axis=0, how='any', inplace=True)

    return total_returns_a
total_returns_a = computing_returns(Data_A, list_of_momentums=1)
total_returns_a['Date'] = Data_A['Date'].iloc[1:].values

#Inflation data
Inflation_Data = pd.read_csv('inflation_monthly.csv')
def computing_returns(Inflation_Data):
        ID_numeric = Inflation_Data.select_dtypes(include=['float64', 'int64'])
        feature_b = ID_numeric.pct_change()
        name = "pct_change"
        feature_b = feature_b.copy()
        feature_b.rename(columns = {0: name}, inplace = True)
        final_df = feature_b
        final_df.dropna(axis=0, how='any', inplace=True)
        return final_df
final_df = computing_returns(Inflation_Data)
final_df['Date'] = Inflation_Data['DATE'].iloc[1:].values

final_df.head()
# Out:
# /var/folders/rj/74d5tm_56lz0_syp098gv5d80000gn/T/ipykernel_55188/1741910622.py:31: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   feature_a = Data_A_numeric.pct_change(i)
#    CORESTICKM159SFRBATL        Date
# 1              0.006013  1968-02-01
# 2              0.127482  1968-03-01
# 3              0.003299  1968-04-01
# 4             -0.016262  1968-05-01
# 5              0.111863  1968-06-01

# %% [markdown]
# ### 2. Interpolate stock returns from daily to monthly

# %%
total_returns['Date'] = pd.to_datetime(total_returns['Date'])
total_returns.set_index('Date', inplace=True)
total_monthly_returns_MSFT = total_returns.resample('M').apply(lambda x: (1 + x).prod() - 1)   
total_monthly_returns_MSFT['MSFT Returns'] = total_monthly_returns_MSFT['Close/Last']

total_returns_a['Date'] = pd.to_datetime(total_returns_a['Date'])
total_returns_a.set_index('Date', inplace=True)
total_monthly_returns_AAPL = total_returns_a.resample('M').apply(lambda x: (1 + x).prod() - 1)  
total_monthly_returns_AAPL['AAPL Returns'] = total_monthly_returns_AAPL['Close/Last']
# Out:
# /var/folders/rj/74d5tm_56lz0_syp098gv5d80000gn/T/ipykernel_55188/896720028.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   total_monthly_returns_MSFT = total_returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
# /var/folders/rj/74d5tm_56lz0_syp098gv5d80000gn/T/ipykernel_55188/896720028.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   total_monthly_returns_AAPL = total_returns_a.resample('M').apply(lambda x: (1 + x).prod() - 1)

# %% [markdown]
# ### 3. Merge the dataframes and calculate / plot the correlation

# %%
Combined_returns = pd.merge(total_monthly_returns_AAPL, total_monthly_returns_MSFT, on= 'Date', how= 'inner')
Combined_returns.head()
# Out:
#             Close/Last_x  AAPL Returns  Close/Last_y  MSFT Returns
# Date
# 2014-05-31     -0.054343     -0.054343     -0.042412     -0.042412
# 2014-06-30     -0.039778     -0.039778     -0.025794     -0.025794
# 2014-07-31     -0.027050     -0.027050     -0.023098     -0.023098
# 2014-08-31     -0.069686     -0.069686     -0.049457     -0.049457
# 2014-09-30      0.041532      0.041532     -0.017647     -0.017647

# %% [markdown]
# ### 4. Calculate the correlation matrix between the Apple returns, Microsoft returns, and inflation change

# %%
# Calculate correlation matrix
correlation_matrix = Combined_returns[['AAPL Returns', 'MSFT Returns']].corr()

# %% [markdown]
# ### 5. Plot the correlation matrix as a heatmap

# %%
# Plot heatmap
#Plot heatmap
sns.heatmap(correlation_matrix, annot = True, cmap = "coolwarm")
plt.title("Feature correlations")
plt.show()

# %% [markdown]
# ## Calculating rolling volatility (standard deviation) of a stock's price for last 3 months
#
# Volatility is a measure of the dispersion of returns for a given security. By calculating rolling volatility, investors can assess the risk associated with a stock over time: Higher volatility indicates higher risk, as the stock's price is more likely to experience significant fluctuations. In portfolio optimization, understanding the volatility of individual stocks and how it changes over time is crucial for diversification and optimization. By analyzing rolling volatility, investors can adjust their portfolios to maintain a desired risk level, potentially improving the risk-return profile.
#
# One possible way to calculate volatility is by using the standard deviation of returns for a stock over time.
#
# Your task:
# * Calculate the weekly rolling standard deviation for Apple's closing price
# * Plot the calculated rolling weekly volatility of Apple's closing price against Apple's closing price. Plot these **on the same chart, but using different y-axes**
#
# Helpful hints:
# * You'll need to use the `pandas` `rolling()` method with a given `window_size` parameter to make it a _weekly_ rolling calculation
# * Use **only the last three months of data**; data much older than this may not be as useful for portfolio optimization
# * You'll need to create two axes on the matplotlib figure to be able to use two different y-axes (one for the closing price and one for the rolling volatility calculated here)

# %%
# Define the window size for the rolling calculation (e.g., one week)
last_three_months = last_three_months.copy()
def computing_volatility(prices, window =7):
    vol = prices.dropna().rolling(window=window).std()
    return vol

# %%
# Calculate rolling one-week volatility
last_three_months['Volatility']= computing_volatility(last_three_months['Close/Last'])
display(last_three_months)
# Out:
#             Close/Last     Volume    Open    High     Low  Volatility
# Date
# 2024-05-03      183.38  163224100  186.65  187.00  182.66         NaN
# 2024-05-02      173.03   94214920  172.51  173.42  170.89         NaN
# 2024-05-01      169.30   50383150  169.58  172.71  169.11         NaN
# 2024-04-30      170.33   65934780  173.33  174.99  170.00         NaN
# 2024-04-29      173.50   68169420  173.37  176.03  173.10         NaN
# ...                ...        ...     ...     ...     ...         ...
# 2024-02-09      188.85   45155220  188.65  189.99  188.00    2.579417
# 2024-02-08      188.32   40962050  189.39  189.54  187.35    2.469760
# 2024-02-07      189.41   53438960  190.64  191.05  188.61    2.313552
# 2024-02-06      189.30   43490760  186.86  189.31  186.77    2.112203
# 2024-02-05      187.68   69668820  188.15  189.25  185.84    1.531914
#
# [63 rows x 6 columns]

# %%
# Plot the calculated rolling weekly volatility of Apple's closing price against Apple's closing price
# Plot these on the same chart, but using different y-axes

fig, ax1 = plt.subplots(figsize=(12,6))

# Plot price (left y-axis)
ax1.plot(last_three_months.index, last_three_months['Close/Last'], color='green', label='Close Price')
ax1.set_ylabel("Close Price (USD)", color='green')
ax1.tick_params(axis='y', labelcolor='green')


ax2 = ax1.twinx()

ax2.plot(last_three_months.index, last_three_months['Volatility']*100, color='red', label='Volatility (%)')  # Multiply by 100 to show %
ax2.set_ylabel("Volatility (%)", color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title("Closing Prices and Volatility Over Time")
ax1.set_xlabel("Date")

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Export data
#
# Now that you have preprocessed your data, you should save it in new csv files so that it can be used in downstream tasks without having to redo all the preprocessing steps.
#
# Your task:
# * Use `pandas` to export all modified datasets back to new CSV files

# %%
last_three_months.to_csv('Apple_three_month_data.csv')
Combined_returns.to_csv('Combined_returns_AAPL_MSFT.csv')
Data.to_csv('GDP_Standardized.csv')
final_df.to_csv('Inflation_data_pct_change.csv')
